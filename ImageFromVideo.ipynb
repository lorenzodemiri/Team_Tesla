# %%
import cv2
import numpy as np


vidcap = cv2.VideoCapture(0)
success,image = vidcap.read()
count = 0
while success:
    cv2.imshow('VideoFeed', image)
    if count % 25 == 0:
        size = (640, 480)
        resized = cv2.resize(image, size)
        cv2.imwrite("frame%d.jpg" % count, resized)     # save frame as JPEG file      
        success,image = vidcap.read()
        print('Read a new frame: ', success)
    count += 1
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

vidcap.release()
cv2.destroyAllWindows()
# Out:
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True
# Read a new frame:  True

# %%
import cv2
import sys
import os
os.environ['DISPLAY'] = ':0'

def show_img(image):
    print('here')
    cv2.imshow('thresh', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()


def extract_frames(path_file, save_path, class_type):
    vidcap = cv2.VideoCapture(path_file)
    count = 0
    success = 1
    while success:
        if success == False: break
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
        success,image = vidcap.read()
        dim = (640, 480)   #DIMESION OF THE RESIZED IMG
        resized = cv2.resize(image, dim)
        cv2.imshow('VideoFeed', resized)
        if count % 20 == 0:
            cv2.imwrite(save_path + "img{}_{}.jpg".format(count ,class_type), resized)     # save frame as JPEG file     
            print('Read a n_', count, ' frame: ', success, "path : ", save_path + "img{}_{}.jpg".format(count ,class_type))
        count += 1
    
    vidcap.release()
    cv2.destroyAllWindows()


def frame_faces_extractor(path_file, save_path, class_type):
    vidcap = cv2.VideoCapture(path_file)
    count = 0
    success = 1
    cascPath = "Haarcascades/haarcascade_frontalface_default.xml"
    faceCascade = cv2.CascadeClassifier(cascPath)
    print("Here")
    while success:
        
        success,image = vidcap.read()
        if success == False: 
            print("EXTRACTION COMPLETED")
            break
            
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
        success,image = vidcap.read()
        dim = (640, 480)   #DIMESION OF THE RESIZED IMG
        resized = cv2.resize(image, dim)   
            
        if count % 20 == 0:
            
            cv2.imwrite(save_path + "imgfull{}_{}.jpg".format(count ,class_type), resized)     # save frame as JPEG file     
            print('Read a n_', count, ' frame: ', success, "path : ", save_path + "imgfull{}_{}.jpg".format(count ,class_type))
            
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        
            faces = faceCascade.detectMultiScale(
                gray,
                scaleFactor=1.1,
                minNeighbors=5,
                minSize=(30, 30),
                flags=cv2.CASCADE_SCALE_IMAGE
            )


        # Draw a rectangle around the faces
            for (x, y, w, h) in faces:
                crop_img = image[y: y +h, x: x + w]
                #cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
            dim = (640, 480)   #DIMESION OF THE RESIZED IMG
            resized = cv2.resize(crop_img, dim)
        
            cv2.imwrite(save_path + "img{}_{}.jpg".format(count ,class_type), resized)     # save frame as JPEG file     
            print('Read a n_', count, ' frame: ', success, "path : ", save_path + "img{}_{}.jpg".format(count ,class_type))
        count += 1
    
    vidcap.release()
    cv2.destroyAllWindows()

def start_capture_test():
    cascPath = "Image_creator_script/haarcascade_frontalface_default.xml"
    faceCascade = cv2.CascadeClassifier(cascPath)

    video_capture = cv2.VideoCapture(0)

    while True:
        # Capture frame-by-frame
        ret, frame = video_capture.read()

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        faces = faceCascade.detectMultiScale(
            gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(30, 30),
            flags=cv2.CASCADE_SCALE_IMAGE
        )

        # Draw a rectangle around the faces
        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

        # Display the resulting frame
        cv2.imshow('Video', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the capture
    video_capture.release()
    cv2.destroyAllWindows()

#start_capture_two("Image_creator_script/test_video.mp4","Image_creator_script/img_ret/no_mask_img/", "NO-MASK")
print("START")
frame_faces_extractor("Image_creator_script/test_video_masked.mp4","Image_creator_script/img_faces_only/masked_images/", "MASKED")
frame_faces_extractor("Image_creator_script/test_video_nomask.mp4","Image_creator_script/img_faces_only/no_mask_images/", "NO-MASKED")

#start_capture_test()
# Out:
# START
# Here
# EXTRACTION COMPLETED
# Here
# EXTRACTION COMPLETED

# %%
#frame_faces_extractor(0, './save/no_mask/', 'no_mask')
#frame_faces_extractor(0, './save/good_mask/', 'good_mask')
frame_faces_extractor(0, './save/bad_mask/', 'bad_mask')
# Out:
# Here
# Read a n_ 0  frame:  True path :  ./save/bad_mask/imgfull0_bad_mask.jpg
# Read a n_ 0  frame:  True path :  ./save/bad_mask/img0_bad_mask.jpg
# Read a n_ 20  frame:  True path :  ./save/bad_mask/imgfull20_bad_mask.jpg
# Read a n_ 20  frame:  True path :  ./save/bad_mask/img20_bad_mask.jpg
# Read a n_ 40  frame:  True path :  ./save/bad_mask/imgfull40_bad_mask.jpg
# Read a n_ 40  frame:  True path :  ./save/bad_mask/img40_bad_mask.jpg
# Read a n_ 60  frame:  True path :  ./save/bad_mask/imgfull60_bad_mask.jpg
# Read a n_ 60  frame:  True path :  ./save/bad_mask/img60_bad_mask.jpg
# Read a n_ 80  frame:  True path :  ./save/bad_mask/imgfull80_bad_mask.jpg
# Read a n_ 80  frame:  True path :  ./save/bad_mask/img80_bad_mask.jpg
# Read a n_ 100  frame:  True path :  ./save/bad_mask/imgfull100_bad_mask.jpg
# Read a n_ 100  frame:  True path :  ./save/bad_mask/img100_bad_mask.jpg
# Read a n_ 120  frame:  True path :  ./save/bad_mask/imgfull120_bad_mask.jpg
# Read a n_ 120  frame:  True path :  ./save/bad_mask/img120_bad_mask.jpg
# Read a n_ 140  frame:  True path :  ./save/bad_mask/imgfull140_bad_mask.jpg
# Read a n_ 140  frame:  True path :  ./save/bad_mask/img140_bad_mask.jpg
# Read a n_ 160  frame:  True path :  ./save/bad_mask/imgfull160_bad_mask.jpg
# Read a n_ 160  frame:  True path :  ./save/bad_mask/img160_bad_mask.jpg
# Read a n_ 180  frame:  True path :  ./save/bad_mask/imgfull180_bad_mask.jpg
# Read a n_ 180  frame:  True path :  ./save/bad_mask/img180_bad_mask.jpg
# Read a n_ 200  frame:  True path :  ./save/bad_mask/imgfull200_bad_mask.jpg
# Read a n_ 200  frame:  True path :  ./save/bad_mask/img200_bad_mask.jpg
# Read a n_ 220  frame:  True path :  ./save/bad_mask/imgfull220_bad_mask.jpg
# Read a n_ 220  frame:  True path :  ./save/bad_mask/img220_bad_mask.jpg
# Read a n_ 240  frame:  True path :  ./save/bad_mask/imgfull240_bad_mask.jpg
# Read a n_ 240  frame:  True path :  ./save/bad_mask/img240_bad_mask.jpg
# Read a n_ 260  frame:  True path :  ./save/bad_mask/imgfull260_bad_mask.jpg
# Read a n_ 260  frame:  True path :  ./save/bad_mask/img260_bad_mask.jpg
# Read a n_ 280  frame:  True path :  ./save/bad_mask/imgfull280_bad_mask.jpg
# Read a n_ 280  frame:  True path :  ./save/bad_mask/img280_bad_mask.jpg
# Read a n_ 300  frame:  True path :  ./save/bad_mask/imgfull300_bad_mask.jpg
# Read a n_ 300  frame:  True path :  ./save/bad_mask/img300_bad_mask.jpg
# Read a n_ 320  frame:  True path :  ./save/bad_mask/imgfull320_bad_mask.jpg
# Read a n_ 320  frame:  True path :  ./save/bad_mask/img320_bad_mask.jpg
# Read a n_ 340  frame:  True path :  ./save/bad_mask/imgfull340_bad_mask.jpg
# Read a n_ 340  frame:  True path :  ./save/bad_mask/img340_bad_mask.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-102-f99a2f12b6e9> in <module>
#       1 #frame_faces_extractor(0, './save/no_mask/', 'no_mask')
#       2 #frame_faces_extractor(0, './save/good_mask/', 'good_mask')
# ----> 3 frame_faces_extractor(0, './save/bad_mask/', 'bad_mask')
#
# <ipython-input-101-6a5ceb0eba38> in frame_faces_extractor(path_file, save_path, class_type)
#      50             break
#      51
# ---> 52         success,image = vidcap.read()
#      53         dim = (640, 480)   #DIMESION OF THE RESIZED IMG
#      54         resized = cv2.resize(image, dim)
#
# KeyboardInterrupt:
